# %%
import numpy as np

# %%
import matplotlib as plt

# %%
from utils import plot_lines

# %%
A = np.array([
        [-1, 3],
        [3, 2]
    ], dtype=np.dtype(float))

b = np.array([7, 1], dtype=np.dtype(float))

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)
# Out:
# Matrix A:
# [[-1.  3.]
#  [ 3.  2.]]
#
# Array b:
# [7. 1.]

# %%
print(f"Shape A: {np.shape(A)}")
print(f"Shape b: {np.shape(b)}")
# Out:
# Shape A: (2, 2)
# Shape b: (2,)

# %%
x=np.linalg.solve(A,b)
print(f"solution:{x}")
# Out:
# solution:[-1.  2.]

# %%
d=np.linalg.det(A)
print(f"Determinant of A:{d:.2f}")
# Out:
# Determinant of A:-11.00

# %%
A_system=np.hstack((A,b.reshape(2,1)))
print(A_system)
# Out:
# [[-1.  3.  7.]
#  [ 3.  2.  1.]]

# %%
print(A_system[1])
# Out:
# [3. 2. 1.]

# %%
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plot_lines(A_system)
#
# TypeError: plot_lines() missing 1 required positional argument: 'y'

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_lines

# %%
A = np.array([
        [-1, 3],
        [3, 2]
    ], dtype=np.dtype(float))

b = np.array([7, 1], dtype=np.dtype(float))

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)
# Out:
# Matrix A:
# [[-1.  3.]
#  [ 3.  2.]]
#
# Array b:
# [7. 1.]

# %%
print(f"Shape A: {np.shape(A)}")
print(f"Shape b: {np.shape(b)}")
# Out:
# Shape A: (2, 2)
# Shape b: (2,)

# %%
x = np.linalg.solve(A, b)
print(f"solution: {x}")
# Out:
# solution: [-1.  2.]

# %%
d = np.linalg.det(A)
print(f"Determinant of A: {d:.2f}")
# Out:
# Determinant of A: -11.00

# %%
A_system = np.hstack((A, b.reshape(2, 1)))
print(A_system)
# Out:
# [[-1.  3.  7.]
#  [ 3.  2.  1.]]

# %%
print(A_system[1])
# Out:
# [3. 2. 1.]

# %%
# Example usage of plot_lines
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Example usage of plot_lines
# ----> 2 plot_lines(A_system)
#
# TypeError: plot_lines() missing 1 required positional argument: 'y'

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_lines

# %%
A = np.array([
        [-1, 3],
        [3, 2]
    ], dtype=np.dtype(float))

b = np.array([7, 1], dtype=np.dtype(float))

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)

# %%
print(f"Shape A: {np.shape(A)}")
print(f"Shape b: {np.shape(b)}")

# %%
x = np.linalg.solve(A, b)
print(f"solution: {x}")

# %%
d = np.linalg.det(A)
print(f"Determinant of A: {d:.2f}")

# %%
A_system = np.hstack((A, b.reshape(2, 1)))
print(A_system)

# %%
print(A_system[1])

# %%
# Example usage of plot_lines
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Example usage of plot_lines
# ----> 2 plot_lines(A_system)
#
# TypeError: plot_lines() missing 1 required positional argument: 'y'

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_lines

# %%
A = np.array([
        [-1, 3],
        [3, 2]
    ], dtype=np.dtype(float))

b = np.array([7, 1], dtype=np.dtype(float))

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)
# Out:
# Matrix A:
# [[-1.  3.]
#  [ 3.  2.]]
#
# Array b:
# [7. 1.]

# %%
print(f"Shape A: {np.shape(A)}")
print(f"Shape b: {np.shape(b)}")
# Out:
# Shape A: (2, 2)
# Shape b: (2,)

# %%
x = np.linalg.solve(A, b)
print(f"solution: {x}")
# Out:
# solution: [-1.  2.]

# %%
d = np.linalg.det(A)
print(f"Determinant of A: {d:.2f}")
# Out:
# Determinant of A: -11.00

# %%
A_system = np.hstack((A, b.reshape(2, 1)))
print(A_system)
# Out:
# [[-1.  3.  7.]
#  [ 3.  2.  1.]]

# %%
print(A_system[1])
# Out:
# [3. 2. 1.]

# %%
# Example usage of plot_lines
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Example usage of plot_lines
# ----> 2 plot_lines(A_system)
#
# TypeError: plot_lines() missing 1 required positional argument: 'y'

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_lines

# %%
A = np.array([
        [-1, 3],
        [3, 2]
    ], dtype=np.dtype(float))

b = np.array([7, 1], dtype=np.dtype(float))

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)
# Out:
# Matrix A:
# [[-1.  3.]
#  [ 3.  2.]]
#
# Array b:
# [7. 1.]

# %%
print(f"Shape A: {np.shape(A)}")
print(f"Shape b: {np.shape(b)}")
# Out:
# Shape A: (2, 2)
# Shape b: (2,)

# %%
x = np.linalg.solve(A, b)
print(f"solution: {x}")
# Out:
# solution: [-1.  2.]

# %%
d = np.linalg.det(A)
print(f"Determinant of A: {d:.2f}")
# Out:
# Determinant of A: -11.00

# %%
A_system = np.hstack((A, b.reshape(2, 1)))
print(A_system)
# Out:
# [[-1.  3.  7.]
#  [ 3.  2.  1.]]

# %%
print(A_system[1])
# Out:
# [3. 2. 1.]

# %%
# Example usage of plot_lines
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Example usage of plot_lines
# ----> 2 plot_lines(A_system)
#
# TypeError: plot_lines() missing 1 required positional argument: 'y'
