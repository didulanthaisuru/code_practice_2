# %%
import numpy as np
import matplotlib.pyplot as plt
import utils

# %%
A=np.array([[2,3],[2,1]])
e1=np.array([[1],[0]])
e2=np.array([[0],[1]])

# %%
utils.plot_transformation(A,e1,e2,vector_name='e')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 utils.plot_transformation(A,e1,e2,vector_name='e')
#
# AttributeError: module 'utils' has no attribute 'plot_transformation'

# %%
import numpy as np
import matplotlib.pyplot as plt
import utils

# Define the matrix and basis vectors
A = np.array([[2, 3], [2, 1]])
e1 = np.array([[1], [0]])
e2 = np.array([[0], [1]])

# Call the plot_transformation function
utils.plot_transformation(A, e1, e2, vector_name='e')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       8 e2 = np.array([[0], [1]])
#      10 # Call the plot_transformation function
# ---> 11 utils.plot_transformation(A, e1, e2, vector_name='e')
#
# AttributeError: module 'utils' has no attribute 'plot_transformation'

# %%
# eigen_vectors.ipynb
import numpy as np
import matplotlib.pyplot as plt
import utils

# Define the matrix and basis vectors
A = np.array([[2, 3], [2, 1]])
e1 = np.array([[1], [0]])
e2 = np.array([[0], [1]])

# Call the plot_transformation function
utils.plot_transformation(A, e1, e2, vector_name='e')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#       9 e2 = np.array([[0], [1]])
#      11 # Call the plot_transformation function
# ---> 12 utils.plot_transformation(A, e1, e2, vector_name='e')
#
# AttributeError: module 'utils' has no attribute 'plot_transformation'
